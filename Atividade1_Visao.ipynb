# %% [markdown]
# # Entregável 1 - visão computacional

# %%
# %matplotlib inline
import cv2
from matplotlib import pyplot as plt
import numpy as np
import time as t
print "OpenCV Version : %s " % cv2.__version__
# Out:
# OpenCV Version : 3.2.0

# %% [markdown]
# # Equalização de histograma

# %%
rintin = cv2.imread("RinTinTin.jpg")

# %%
rintin.shape
# Out:
# (240L, 320L, 3L)

# %%
rintin_gray = cv2.cvtColor(rintin, cv2.COLOR_RGB2GRAY)

# %%
rintin_gray.shape
# Out:
# (240L, 320L)

# %%
plt.imshow(rintin_gray, cmap="Greys_r", vmin=0, vmax=255)

# %%
hist,bins = np.histogram(rintin_gray.flatten(),256,[0,256])


cdf = hist.cumsum()
cdf_normalized = cdf * hist.max()/ cdf.max()

plt.plot(cdf_normalized, color = 'b')
plt.hist(rintin_gray.flatten(),256,[0,256], color = 'r')
plt.xlim([0,256])
plt.legend(('cdf','histogram'), loc = 'upper left')
plt.show()

# %% [markdown]
# ## Atividade 1
#
# Realize as seguintes atividades:
#
# 1. O histograma fornecido aproveita bem as faixas de cores?
# 2. Equalize o histograma de maneira que a cumulativa seja uma função linear na diagonal do gráfico
# 3. Plote a imagem desenhada

# %% [markdown]
# 1) Não, uma vez que concentra boa partes dos pixels  em uma faixa muito pequena do espectro de cores

# %%
histeq=[]
histeq=rintin_gray
def norm(x):
    return (((x-8)*255)/50)

for i in range(len(rintin_gray)):
    var1=[]
    var1=rintin_gray[i]
    for j in range(len(rintin_gray[i])):
        x=norm(rintin_gray[i][j]) 
        var1[j]=x
    histeq[i]=var1

# %%
hist,bins = np.histogram(histeq.flatten(),256,[0,256])

cdf = hist.cumsum()
cdf_normalized = cdf * hist.max()/ cdf.max()



plt.plot(cdf_normalized, color = 'b')
plt.hist(histeq.flatten(),256,[0,256], color = 'r')
plt.xlim([0,256])
plt.legend(('cdf','histogram'), loc = 'upper left')
plt.show()

# %%
histeq=[]

x=hist

y=((x-8)*255)/50

histeq.append(y)

print histeq

# %%
plt.imshow(histeq, cmap="Greys_r", vmin=0, vmax=255)

# %% [markdown]
# ## Atividade 2

# %% [markdown]
# Leia com a OpenCV a figura abaixo:
#
# ![](hall_box_battery1.jpg)
#
# Separe os canais  R e B das imagens e analise seus histogramas.
#
# 1. A partir dos canais R e B e da análise do histograma é possível identificar a caixa vermelha e a bateria azul?
#
# 1. Crie uma imagem numpy em que somente os pixels da caixa vermelha estão brancos e faça seu plot aqui

# %%
hall = cv2.imread("hall_box_battery1.jpg")
hall = cv2.cvtColor(hall,cv2.COLOR_BGR2RGB)
plt.imshow(hall, cmap="Greys_r", vmin=0, vmax=255)
plt.show()

# %%
hall_r = hall[:,:,0]

#heq2 = cv2.equalizeHist(hall_r)
#plt.imshow(hall_r,cmap="Greys_r")
plt.hist(hall_r.ravel(),256,[0,256], color = 'r')
plt.xlim([0,256])
plt.show()

# %%
hall_b = hall[:,:,2]


plt.hist(hall_b.ravel(),256,[0,256], color = 'b')
plt.xlim([0,256])
plt.show()

# %%
plt.imshow(hall_r, cmap="Greys_r", vmin=0, vmax=255)

# %%
plt.imshow(hall_b, cmap="Greys_r", vmin=0, vmax=255)
